# %% [markdown]
# # ZQ0914-TITLE
#
# inert marker ZQ0914-MD-TEXT

# %% [markdown]
# <div id="ZQ0914-MD-DIV" class="ZQ0914-MD-CLASS" data-gadget="ZQ0914-MD-DATA">ZQ0914-MD-DIV-INNER</div>

# %% [markdown]
# <img id="ZQ0914-MD-IMG" src="x" onerror="window.ZQ0914_MD_IMG=1">

# %% [markdown]
# <a id="ZQ0914-MD-A" href="javascript:window.ZQ0914_MD_A=1">ZQ0914-MD-A-TEXT</a>

# %% [markdown]
# <iframe id="ZQ0914-MD-IFRAME" srcdoc="ZQ0914-MD-IFRAME-INNER"></iframe>

# %% [markdown]
# <svg id="ZQ0914-MD-SVG"><script>window.ZQ0914_MD_SVG=1</script></svg>

# %% [markdown]
# <form id="ZQ0914-MD-FORM" action="//example.org"><input name="ZQ0914-MD-INPUT"></form>

# %% [markdown]
# <style id="ZQ0914-MD-STYLE">.ZQ0914-MD-STYLECLASS{color:red}</style>

# %% [markdown]
# <math id="ZQ0914-MD-MATH"><mtext>ZQ0914-MD-MATH-INNER</mtext></math>

# %% [markdown]
# <template id="ZQ0914-MD-TEMPLATE">ZQ0914-MD-TEMPLATE-INNER</template>

# %% [markdown]
# <div data-main="ZQ0914-MD-DATAMAIN" data-target="ZQ0914-MD-DATATARGET" data-action="click:ZQ0914-MD-DATAACTION">ZQ0914-MD-DATAWRAP</div>

# %% [markdown]
# $\href{javascript:window.ZQ0914_TEX_HREF=1}{ZQ0914-TEX-HREF}$

# %% [markdown]
# $\class{ZQ0914-TEX-CLASS}{x}\style{color:red}{y}$

# %% [markdown]
# $\cssId{ZQ0914-TEX-CSSID}{z}$

# %%
pass
# Out:
# <div id="ZQ0914-OUT-HTML-DIV" data-gadget="ZQ0914-OUT-HTML-DATA">ZQ0914-OUT-HTML-INNER</div><img id="ZQ0914-OUT-HTML-IMG" src=x onerror="window.ZQ0914_OUT_IMG=1">

# %%
pass

# %%
pass

# %%
pass
# Out:
# $\href{javascript:window.ZQ0914_OUT_TEX=1}{ZQ0914-OUT-TEX}$

# %%
pass
# Out:
# <div id="ZQ0914-OUT-MD-DIV">ZQ0914-OUT-MD-INNER</div>

# %%
pass
# Out:
# ZQ0914-OUT-PLAIN <b id="ZQ0914-OUT-PLAIN-B">x</b>
